# %%
from model_helper import *
import numpy
# Out:
# Using TensorFlow backend.

# %%
num_layer = 2

path = 'corpus/linux_kernel_val.txt'
model_weights = 'models/corpus_linux_kernel_val_architecture_stateful_type_char_layers_2_hidden_units_128_epoch_49_weights.h5'
model_settings_name = 'settings/corpus_linux_kernel_architecture_stateful_type_char_layers_2_hidden_units_128_settings.pickle'
new_batch_size = 1
new_size = 1
new_time_skip = 1
is_stateful = True

# Loads the model
model, inverting_dict, identity_dict, raw_dataset, filtered_vocab  = \
    load_setup(num_layer,
                path,model_weights,
                model_settings_name ,
                new_batch_size,
                new_size,
                new_time_skip,
                is_stateful)
# Out:
# 128
# lstm_2
# 128
# lstm_3
# Loading model settings/corpus_linux_kernel_architecture_stateful_type_char_layers_2_hidden_units_128_settings.pickle
# Reading file corpus/linux_kernel_val.txt
# Number of Words in Current Corpus: 6206996

# %%
[inverting_dict[c] for c in raw_dataset]
# Out:
# [17,
#  14,
#  1,
#  4,
#  14,
#  4,
#  57,
#  52,
#  59,
#  64,
#  69,
#  17,
#  54,
#  48,
#  63,
#  59,
#  48,
#  57,
#  17,
#  52,
#  63,
#  60,
#  17,
#  44,
#  64,
#  65,
#  58,
#  61,
#  63,
#  58,
#  47,
#  48,
#  18,
#  46,
#  1,
#  4,
#  14,
#  1,
#  4,
#  14,
#  4,
#  46,
#  58,
#  61,
#  68,
#  63,
#  52,
#  50,
#  53,
#  65,
#  4,
#  12,
#  46,
#  11,
#  4,
#  19,
#  27,
#  27,
#  22,
#  16,
#  4,
#  19,
#  27,
#  27,
#  28,
#  15,
#  22,
#  20,
#  20,
#  24,
#  4,
#  57,
#  52,
#  59,
#  64,
#  62,
#  4,
#  65,
#  58,
#  63,
#  67,
#  44,
#  57,
#  49,
#  62,
#  16,
#  4,
#  52,
#  59,
#  50,
#  58,
#  4,
#  56,
#  58,
#  57,
#  59,
#  44,
#  63,
#  1,
#  4,
#  14,
#  1,
#  4,
#  14,
#  4,
#  65,
#  53,
#  52,
#  62,
#  4,
#  51,
#  52,
#  57,
#  48,
#  4,
#  46,
#  58,
#  59,
#  65,
#  44,
#  52,
#  59,
#  62,
#  4,
#  65,
#  53,
#  48,
#  4,
#  52,
#  59,
#  65,
#  48,
#  63,
#  63,
#  64,
#  61,
#  65,
#  4,
#  61,
#  63,
#  58,
#  47,
#  52,
#  59,
#  50,
#  4,
#  46,
#  58,
#  49,
#  48,
#  4,
#  44,
#  59,
#  49,
#  4,
#  49,
#  63,
#  52,
#  67,
#  48,
#  63,
#  4,
#  44,
#  61,
#  52,
#  62,
#  18,
#  1,
#  4,
#  14,
#  17,
#  1,
#  1,
#  5,
#  52,
#  59,
#  46,
#  57,
#  64,
#  49,
#  48,
#  4,
#  32,
#  57,
#  52,
#  59,
#  64,
#  69,
#  17,
#  52,
#  63,
#  60,
#  18,
#  53,
#  34,
#  1,
#  5,
#  52,
#  59,
#  46,
#  57,
#  64,
#  49,
#  48,
#  4,
#  32,
#  57,
#  52,
#  59,
#  64,
#  69,
#  17,
#  56,
#  58,
#  49,
#  64,
#  57,
#  48,
#  18,
#  53,
#  34,
#  1,
#  5,
#  52,
#  59,
#  46,
#  57,
#  64,
#  49,
#  48,
#  4,
#  32,
#  57,
#  52,
#  59,
#  64,
#  69,
#  17,
#  52,
#  59,
#  65,
#  48,
#  63,
#  63,
#  64,
#  61,
#  65,
#  18,
#  53,
#  34,
#  1,
#  5,
#  52,
#  59,
#  46,
#  57,
#  64,
#  49,
#  48,
#  4,
#  32,
#  57,
#  52,
#  59,
#  64,
#  69,
#  17,
#  49,
#  48,
#  57,
#  44,
#  68,
#  18,
#  53,
#  34,
#  1,
#  5,
#  52,
#  59,
#  46,
#  57,
#  64,
#  49,
#  48,
#  4,
#  32,
#  57,
#  52,
#  59,
#  64,
#  69,
#  17,
#  44,
#  62,
#  68,
#  59,
#  46,
#  18,
#  53,
#  34,
#  1,
#  1,
#  5,
#  52,
#  59,
#  46,
#  57,
#  64,
#  49,
#  48,
#  4,
#  6,
#  52,
#  59,
#  65,
#  48,
#  63,
#  59,
#  44,
#  57,
#  62,
#  18,
#  53,
#  6,
#  1,
#  1,
#  17,
#  14,
#  1,
#  4,
#  14,
#  4,
#  44,
#  64,
#  65,
#  58,
#  49,
#  48,
#  65,
#  48,
#  46,
#  65,
#  52,
#  58,
#  59,
#  4,
#  49,
#  48,
#  61,
#  48,
#  59,
#  49,
#  62,
#  4,
#  58,
#  59,
#  4,
#  65,
#  53,
#  48,
#  4,
#  51,
#  44,
#  46,
#  65,
#  4,
#  65,
#  53,
#  44,
#  65,
#  4,
#  44,
#  59,
#  68,
#  4,
#  52,
#  59,
#  65,
#  48,
#  63,
#  63,
#  64,
#  61,
#  65,
#  4,
#  65,
#  53,
#  44,
#  65,
#  1,
#  4,
#  14,
#  4,
#  46,
#  58,
#  56,
#  48,
#  62,
#  4,
#  52,
#  59,
#  4,
#  58,
#  59,
#  4,
#  65,
#  58,
#  4,
#  44,
#  59,
#  4,
#  64,
#  59,
#  44,
#  62,
#  62,
#  52,
#  50,
#  59,
#  48,
#  49,
#  4,
#  53,
#  44,
#  59,
#  49,
#  57,
#  48,
#  63,
#  4,
#  66,
#  52,
#  57,
#  57,
#  4,
#  50,
#  48,
#  65,
#  4,
#  62,
#  65,
#  64,
#  46,
#  54,
#  4,
#  66,
#  52,
#  65,
#  53,
#  1,
#  4,
#  14,
#  4,
#  6,
#  52,
#  63,
#  60,
#  62,
#  42,
#  66,
#  44,
#  52,
#  65,
#  52,
#  59,
#  50,
#  6,
#  4,
#  46,
#  57,
#  48,
#  44,
#  63,
#  48,
#  49,
#  4,
#  44,
#  59,
#  49,
#  4,
#  65,
#  53,
#  48,
#  4,
#  52,
#  59,
#  65,
#  48,
#  63,
#  63,
#  64,
#  61,
#  65,
#  4,
#  49,
#  52,
#  62,
#  44,
#  47,
#  57,
#  48,
#  49,
#  18,
#  1,
#  4,
#  14,
#  17,
#  1,
#  62,
#  65,
#  44,
#  65,
#  52,
#  46,
#  4,
#  49,
#  48,
#  51,
#  52,
#  59,
#  48,
#  42,
#  56,
#  64,
#  65,
#  48,
#  69,
#  12,
#  61,
#  63,
#  58,
#  47,
#  52,
#  59,
#  50,
#  42,
#  44,
#  46,
#  65,
#  52,
#  67,
#  48,
#  11,
#  29,
#  1,
#  1,
#  17,
#  14,
#  14,
#  1,
#  4,
#  14,
#  0,
#  61,
#  63,
#  58,
#  47,
#  48,
#  42,
#  52,
#  63,
#  60,
#  42,
#  58,
#  59,
#  0,
#  15,
#  4,
#  47,
#  48,
#  50,
#  52,
#  59,
#  4,
#  44,
#  59,
#  4,
#  52,
#  59,
#  65,
#  48,
#  63,
#  63,
#  64,
#  61,
#  65,
#  4,
#  44,
#  64,
#  65,
#  58,
#  49,
#  48,
#  65,
#  48,
#  46,
#  65,
#  1,
#  4,
#  14,
#  1,
#  4,
#  14,
#  0,
#  46,
#  58,
#  56,
#  56,
#  48,
#  59,
#  46,
#  48,
#  4,
#  61,
#  63,
#  58,
#  47,
#  52,
#  59,
#  50,
#  4,
#  51,
#  58,
#  63,
#  4,
#  44,
#  59,
#  4,
#  52,
#  59,
#  65,
#  48,
#  63,
#  63,
#  64,
#  61,
#  65,
#  18,
#  4,
#  65,
#  53,
#  48,
#  4,
#  52,
#  59,
#  65,
#  48,
#  63,
#  63,
#  64,
#  61,
#  65,
#  62,
#  4,
#  44,
#  63,
#  48,
#  4,
#  62,
#  46,
#  44,
#  59,
#  59,
#  48,
#  49,
#  1,
#  4,
#  14,
#  0,
#  44,
#  59,
#  49,
#  4,
#  44,
#  4,
#  56,
#  44,
#  62,
#  54,
#  4,
#  58,
#  51,
#  4,
#  61,
#  58,
#  65,
#  48,
#  59,
#  65,
#  52,
#  44,
#  57,
#  4,
#  52,
#  59,
#  65,
#  48,
#  63,
#  63,
#  64,
#  61,
#  65,
#  4,
#  57,
#  52,
#  59,
#  48,
#  62,
#  4,
#  52,
#  62,
#  4,
#  63,
#  48,
#  65,
#  64,
#  63,
#  59,
#  48,
#  49,
#  18,
#  1,
#  4,
#  14,
#  1,
#  4,
#  14,
#  17,
#  1,
#  64,
#  59,
#  62,
#  52,
#  50,
#  59,
#  48,
#  49,
#  4,
#  57,
#  58,
#  59,
#  50,
#  4,
#  61,
#  63,
#  58,
#  47,
#  48,
#  42,
#  52,
#  63,
#  60,
#  42,
#  58,
#  59,
#  12,
#  67,
#  58,
#  52,
#  49,
#  11,
#  1,
#  70,
#  1,
#  0,
#  62,
#  65,
#  63,
#  64,
#  46,
#  65,
#  4,
#  52,
#  63,
#  60,
#  42,
#  49,
#  48,
#  62,
#  46,
#  4,
#  14,
#  49,
#  48,
#  62,
#  46,
#  29,
#  1,
#  0,
#  64,
#  59,
#  62,
#  52,
#  50,
#  59,
#  48,
#  49,
#  4,
#  57,
#  58,
#  59,
#  50,
#  4,
#  56,
#  44,
#  62,
#  54,
#  4,
#  31,
#  4,
#  20,
#  29,
#  1,
#  0,
#  52,
#  59,
#  65,
#  4,
#  52,
#  29,
#  1,
#  1,
#  0,
#  17,
#  14,
#  1,
#  0,
#  4,
#  14,
#  4,
#  60,
#  64,
#  52,
#  48,
#  62,
#  46,
#  48,
#  4,
#  65,
#  53,
#  48,
#  4,
#  54,
#  48,
#  63,
#  59,
#  48,
#  57,
#  16,
#  4,
#  58,
#  63,
#  4,
#  44,
#  65,
#  4,
#  57,
#  48,
#  44,
#  62,
#  65,
#  4,
#  65,
#  53,
#  48,
#  4,
#  44,
#  62,
#  68,
#  59,
#  46,
#  53,
#  63,
#  58,
#  59,
#  58,
#  64,
#  62,
#  4,
#  61,
#  58,
#  63,
#  65,
#  52,
#  58,
#  59,
#  1,
#  0,
#  4,
#  14,
#  17,
#  1,
#  0,
#  44,
#  62,
#  68,
#  59,
#  46,
#  42,
#  62,
#  68,
#  59,
#  46,
#  53,
#  63,
#  58,
#  59,
#  52,
#  71,
#  48,
#  42,
#  51,
#  64,
#  57,
#  57,
#  12,
#  11,
#  29,
#  1,
#  0,
#  56,
#  64,
#  65,
#  48,
#  69,
#  42,
#  57,
#  58,
#  46,
#  54,
#  12,
#  10,
#  61,
#  63,
#  58,
#  47,
#  52,
#  59,
#  50,
#  42,
#  44,
#  46,
#  65,
#  52,
#  67,
#  48,
#  11,
#  29,
#  1,
#  0,
#  17,
#  14,
#  1,
#  0,
#  4,
#  14,
#  4,
#  62,
#  58,
#  56,
#  48,
#  65,
#  53,
#  52,
#  59,
#  50,
#  4,
#  56,
#  44,
#  68,
#  4,
#  53,
#  44,
#  67,
#  48,
#  4,
#  50,
#  48,
#  59,
#  48,
#  63,
#  44,
#  65,
#  48,
#  49,
#  4,
#  44,
#  59,
#  4,
#  52,
#  63,
#  60,
#  4,
#  57,
#  58,
#  59,
#  50,
#  4,
#  44,
#  50,
#  ...]
